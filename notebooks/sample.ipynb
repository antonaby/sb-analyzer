# %%
from core.apify import create_apify_client, download_video
from core.videos import split_video

client = create_apify_client()

# %%
video = await download_video(client, "jwdW1aEE7nZB6behY", "video-abrajerril-20251001021835-7556071963177831711.mp4")
frames = split_video(video)

# %%
from core.agents.analyzer import analyze_frame

result = await analyze_frame(frames[0])
result
# Out:
# ClipTaggerResponse(description='A calico cat walks towards the camera on a paved patio, followed by several small kittens. In the background, there is a pink vending machine, a wooden pallet, and a red plastic chair. The patio is made of light-colored paving stones. White text with a black outline is overlaid on the bottom of the image.', objects=['Calico cat', 'Kittens', 'Paved patio', 'Pink vending machine', 'Wooden pallet', 'Red plastic chair', 'English text', 'Emoji', 'Wooden fence', 'White hose'], actions=['A cat walking towards the camera on a patio.', 'Kittens following a mother cat.'], environment='An outdoor paved patio or backyard area with a wooden fence in the background. The ground is made of light-colored paving stones, and there are various objects like a vending machine and a pallet scattered around.', content_type='real-world footage', specific_style='social media video', production_quality='amateur', summary='A calico cat walks towards the camera on a paved patio, followed by her litter of kittens, with a text overlay describing the scene.', logos=[])
