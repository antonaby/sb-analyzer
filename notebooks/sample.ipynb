# %%
from core.apify import create_apify_client, download_and_split_video

client = create_apify_client()

# %%
frames = await download_and_split_video(client, "jwdW1aEE7nZB6behY", "video-abrajerril-20251001021835-7556071963177831711.mp4")

# %%
from core.agents.analyzer import analyze_frames
import logging
logging.basicConfig(level=logging.DEBUG)

result = await analyze_frames(frames['frames'][0])
result
