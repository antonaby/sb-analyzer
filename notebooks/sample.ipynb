# %%
from core.apify import create_apify_client, download_video
from core.videos import split_video
from core.agents.analyzer import VideoAnalyzer

client = create_apify_client()

# %%
video = await download_video(client, "jwdW1aEE7nZB6behY", "video-funnyfjn-20251001024805-7556079475377589518.mp4")
details = split_video(video, interval_seconds=10)

# %%
analyzer = VideoAnalyzer()
summary = await analyzer.summary(details)
summary
# Out:
# {'frames': [{'frame': {'base64': '...',
#     'frame_number': 0,
#     'timestamp': 0},
#    'description': ClipTaggerResponse(description='A man with glasses and a goatee, wearing a black suit and a pink tie, holds a fluffy, long-haired cat. The cat, which is light brown and white, stands on a white-topped table. In the background, there is a sign with the number 14 on it. White text at the bottom of the frame reads "The best cat show".', objects=['Man with glasses and a goatee', 'Fluffy cat with long brown and white fur', 'Black suit jacket', 'Pink tie', 'White-topped table', 'Sign with the number 14', 'English text', 'Sisal rope scratching post', 'Red and white rosette'], actions=['A man holding a cat on a table.', 'A cat standing on a table.'], environment='An indoor setting, likely a room set up for a cat show, with a table, a sign, and a scratching post visible.', content_type='real-world footage', specific_style='social media video', production_quality='amateur handheld', summary='A man in a suit holds a fluffy cat on a table in what appears to be a cat show, with text overlaying the image.', logos=['A small cartoon cat head icon in the bottom left corner.']),
#    'input_tokens': 936,
#    'output_tokens': 335},
#   {'frame': {'base64': '...',
#     'frame_number': 300,
#     'timestamp': 10},
#    'description': ClipTaggerResponse(description='A woman with blonde hair holds a brown cat that is standing on its hind legs on a wooden table. The cat is wearing a yellow and black bee costume and is holding onto a scratching post with its front paws. In the background, there is a metal cage and a white bottle on the table.', objects=['Brown cat', 'Woman with blonde hair', 'Bee costume', 'Scratching post', 'Wooden table', 'Metal cage', 'White bottle', 'Blue shirt', 'Patterned vest', 'Cartoon cat icon'], actions=['A woman holds a cat on a table.', 'A cat stands on its hind legs while wearing a costume.', 'A cat holds onto a scratching post with its front paws.'], environment='An indoor room with a plain gray wall. The scene is set on a wooden table, with a scratching post and a metal cage visible in the background.', content_type='real-world footage', specific_style='social media video', production_quality='amateur handheld', summary='A woman holds a brown cat that is standing on its hind legs on a table while wearing a bee costume and holding onto a scratching post.', logos=['A small, stylized cartoon cat face with a purple outline and a pink nose, located in the bottom left corner.']),
#    'input_tokens': 936,
#    'output_tokens': 338},
#   {'frame': {'base64': '...',
#     'frame_number': 600,
#     'timestamp': 20},
#    'description': ClipTaggerResponse(description="A man with short dark hair, wearing a black t-shirt, is holding a calico cat in his arms. The cat is lying on its back, looking up at the man with its mouth open. In the background, there is a white cabinet with glass doors and a yellow cabinet. The back of another cat's head is visible in the foreground.", objects=['Man with short dark hair', 'Calico cat', 'Black t-shirt', 'White cabinet with glass doors', 'Yellow cabinet', "Watch on man's wrist", 'Cartoon cat sticker'], actions=['A man holding a cat in his arms.', "A cat lying on its back in a man's arms."], environment='An indoor room with warm, artificial lighting. The background consists of a white cabinet with glass doors and a yellow cabinet, suggesting a kitchen or living area.', content_type='real-world footage', specific_style='social media video', production_quality='amateur handheld', summary='A man in a black t-shirt holds a calico cat that is lying on its back in his arms inside a room.', logos=[]),
#    'input_tokens': 936,
#    'output_tokens': 297},
#   {'frame': {'base64': '...',
#     'frame_number': 900,
#     'timestamp': 30},
#    'description': ClipTaggerResponse(description='A man with a beard and a baseball cap is holding a tabby and white cat. The man is wearing a black t-shirt and a watch on his left wrist. He is gesturing with his right hand while looking towards the camera. In the background, there are curtains and a black couch.', objects=['Man with a beard', 'Tabby and white cat', 'Baseball cap', 'Black t-shirt', 'Black watch', 'Curtains', 'Black couch'], actions=['A man holding a cat in his arms.', 'A man gesturing with his right hand.'], environment='The setting is an indoor room, likely a living room, with dim, warm lighting. A black couch and patterned curtains are visible in the background.', content_type='real-world footage', specific_style='social media video', production_quality='amateur handheld', summary='A man with a beard and a baseball cap holds a tabby and white cat while gesturing with his hand in a dimly lit room.', logos=["A small, white, cartoon-style logo of a cat's head with a pink bow, located at the bottom center of the frame."]),
#    'input_tokens': 936,
#    'output_tokens': 305},
#   {'frame': {'base64': '...',
#     'frame_number': 1200,
#     'timestamp': 40},
#    'description': ClipTaggerResponse(description="A bald man in a white shirt and tie holds a long-haired orange cat on a wooden table. The cat is standing on its hind legs, looking towards the man. In the background, other people are visible behind a barrier, and there are signs for a company and a website. The back of a person's head is in the foreground.", objects=['Long-haired orange cat', 'Bald man in a white shirt and tie', 'Wooden table', 'Green banner with white text', 'English text', 'Small wooden stool', 'Blue bottle', 'Sign with the number 173', "Person's head with dark hair", 'Cartoon cat emoji'], actions=['A man holding a cat on a table.', 'People watching an event in the background.'], environment='An indoor event space, likely a convention hall or exhibition center, with booths, tables, and a crowd of people. The lighting appears to be standard overhead lighting.', content_type='real-world footage', specific_style='Social media video', production_quality='amateur handheld', summary='A bald man holds a long-haired orange cat on a table at what appears to be a cat show or exhibition.', logos=["Renewal by Andersen logo, featuring the text 'Renewal by Andersen' and a stylized 'A' with a house shape inside."]),
#    'input_tokens': 936,
#    'output_tokens': 352},
#   {'frame': {'base64': '...',
#     'frame_number': 1500,
#     'timestamp': 50},
#    'description': ClipTaggerResponse(description='A man with blonde hair holds a ginger cat up in the air. The man is wearing a blue and white patterned shirt and is looking towards the camera. In the background, there are tables, a blue wall, and what appear to be animal cages. White text at the top of the image reads "The best cat show".', objects=['Ginger cat', 'Man with blonde hair', 'Blue and white patterned shirt', 'English text', 'White table', 'Paper document', 'Animal cages', 'Blue wall', 'Cartoon cat sticker'], actions=['A man holding a cat up in the air.', 'A man looking at the camera.'], environment='An indoor event hall, likely a cat show, with blue walls, tables covered in white cloths, and animal cages in the background. The lighting appears to be from overhead fixtures.', content_type='real-world footage', specific_style='Social media video', production_quality='amateur handheld', summary='A man in a blue patterned shirt holds a ginger cat up in the air at what appears to be a cat show.', logos=[]),
#    'input_tokens': 936,
#    'output_tokens': 293},
#   {'frame': {'base64': '...',
#     'frame_number': 1800,
#     'timestamp': 60},
#    'description': ClipTaggerResponse(description="A man with white hair, wearing a suit and tie, sits at a table. In front of him, a large, fluffy white cat walks across the table's surface. The background features a black curtain and hanging purple flowers. To the left is a scratching post, and to the right is a small sign with the number 102.", objects=['Man with white hair', 'Fluffy white cat', 'English text', 'Purple flowers', 'Scratching post', 'Table', 'Sign with the number 102', 'Black curtain', 'Cartoon cat sticker'], actions=['A man sitting at a table', 'A cat walking on a table'], environment='An indoor setting, likely a cat show or exhibition, with a black curtain backdrop, hanging purple flowers, and a table set up for a presentation.', content_type='real-world footage', specific_style='social media video', production_quality='amateur handheld', summary='A man in a suit sits at a table while a large, fluffy white cat walks in front of him at what appears to be a cat show.', logos=[]),
#    'input_tokens': 936,
#    'output_tokens': 299}],
#  'transcription': {'task': 'translate',
#   'language': 'en',
#   'duration': 68.802125,
#   'text': "this is a domestic short hair a long tail big nuts this is a cat you don't ask anything of he's 10 years old yeah okay you can stay there you've got to be from 20 something years I have a good one of them I never had one like this never",
#   'segments': [{'id': 0,
#     'text': "this is a domestic short hair a long tail big nuts this is a cat you don't ask anything of he's 10 years old",
#     'start': 0.28,
#     'end': 39.56,
#     'avg_logprob': -0.3154108226299286,
#     'language': 'en',
#     'speaker': 'SPEAKER_01',
#     'words': [{'word': 'this',
#       'start': 0.28,
#       'end': 0.78,
#       'score': 0,
#       'speaker': 'SPEAKER_00'},
#      {'word': 'is',
#       'start': 0.78,
#       'end': 0.8,
#       'score': 0.75,
#       'speaker': 'SPEAKER_00'},
#      {'word': 'a',
#       'start': 0.8,
#       'end': 1.1,
#       'score': 0.22,
#       'speaker': 'SPEAKER_00'},
#      {'word': 'domestic',
#       'start': 1.1,
#       'end': 1.36,
#       'score': 0,
#       'speaker': 'SPEAKER_00'},
#      {'word': 'short',
#       'start': 1.36,
#       'end': 6.5,
#       'score': 0,
#       'speaker': 'SPEAKER_00'},
#      {'word': 'hair',
#       'start': 6.5,
#       'end': 23.82,
#       'score': 0.07,
#       'speaker': 'SPEAKER_01'},
#      {'word': 'a',
#       'start': 26.04,
#       'end': 26.26,
#       'score': 0.01,
#       'speaker': 'SPEAKER_04'},
#      {'word': 'long',
#       'start': 26.26,
#       'end': 26.86,
#       'score': 0.99,
#       'speaker': 'SPEAKER_04'},
#      {'word': 'tail',
#       'start': 26.86,
#       'end': 27.74,
#       'score': 0.95,
#       'speaker': 'SPEAKER_04'},
#      {'word': 'big',
#       'start': 27.74,
#       'end': 28.44,
#       'score': 0.35,
#       'speaker': 'SPEAKER_04'},
#      {'word': 'nuts',
#       'start': 28.44,
#       'end': 28.78,
#       'score': 0.73,
#       'speaker': 'SPEAKER_04'},
#      {'word': 'this',
#       'start': 29.44,
#       'end': 30,
#       'score': 0,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'is',
#       'start': 30,
#       'end': 31.2,
#       'score': 0.7,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'a',
#       'start': 31.2,
#       'end': 33.7,
#       'score': 0.48,
#       'speaker': 'SPEAKER_04'},
#      {'word': 'cat',
#       'start': 33.7,
#       'end': 33.9,
#       'score': 0.81,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'you',
#       'start': 33.9,
#       'end': 34.1,
#       'score': 0.44,
#       'speaker': 'SPEAKER_03'},
#      {'word': "don't",
#       'start': 34.1,
#       'end': 34.32,
#       'score': 0.84,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'ask',
#       'start': 34.32,
#       'end': 34.66,
#       'score': 0.95,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'anything',
#       'start': 34.66,
#       'end': 35.08,
#       'score': 0.93,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'of',
#       'start': 35.08,
#       'end': 35.94,
#       'score': 0.16,
#       'speaker': 'SPEAKER_03'},
#      {'word': "he's",
#       'start': 35.94,
#       'end': 36.56,
#       'score': 0.56,
#       'speaker': 'SPEAKER_03'},
#      {'word': '10',
#       'start': 38.26,
#       'end': 38.5,
#       'score': 0.63,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'years',
#       'start': 38.5,
#       'end': 38.84,
#       'score': 0.99,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'old',
#       'start': 38.84,
#       'end': 39.56,
#       'score': 0.97,
#       'speaker': 'SPEAKER_03'}]},
#    {'id': 1,
#     'text': "yeah okay you can stay there you've got to be from 20 something years",
#     'start': 52.1,
#     'end': 59.16,
#     'avg_logprob': -0.6700305938720703,
#     'language': 'en',
#     'speaker': 'SPEAKER_02',
#     'words': [{'word': 'yeah',
#       'start': 52.1,
#       'end': 53.96,
#       'score': 0.01,
#       'speaker': 'SPEAKER_00'},
#      {'word': 'okay',
#       'start': 53.96,
#       'end': 55.26,
#       'score': 0.06,
#       'speaker': 'SPEAKER_02'},
#      {'word': 'you',
#       'start': 55.26,
#       'end': 55.56,
#       'score': 0.72,
#       'speaker': 'SPEAKER_02'},
#      {'word': 'can',
#       'start': 55.56,
#       'end': 55.6,
#       'score': 0.99,
#       'speaker': 'SPEAKER_02'},
#      {'word': 'stay',
#       'start': 55.6,
#       'end': 55.8,
#       'score': 0.96,
#       'speaker': 'SPEAKER_02'},
#      {'word': 'there',
#       'start': 55.8,
#       'end': 56.86,
#       'score': 0.99,
#       'speaker': 'SPEAKER_02'},
#      {'word': "you've",
#       'start': 56.86,
#       'end': 57.58,
#       'score': 0.02,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'got',
#       'start': 57.58,
#       'end': 57.58,
#       'score': 0.63,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'to',
#       'start': 57.58,
#       'end': 57.76,
#       'score': 0.19,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'be',
#       'start': 57.76,
#       'end': 57.88,
#       'score': 0.66,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'from',
#       'start': 57.88,
#       'end': 58.04,
#       'score': 0.24,
#       'speaker': 'SPEAKER_03'},
#      {'word': '20',
#       'start': 58.04,
#       'end': 58.44,
#       'score': 0.65,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'something',
#       'start': 58.44,
#       'end': 58.8,
#       'score': 0.72,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'years',
#       'start': 58.8,
#       'end': 59.16,
#       'score': 0.91,
#       'speaker': 'SPEAKER_03'}]},
#    {'id': 2,
#     'text': 'I have a good one of them I never had one like this never',
#     'start': 59.88,
#     'end': 62.86,
#     'avg_logprob': -0.2138298600912094,
#     'language': 'en',
#     'speaker': 'SPEAKER_03',
#     'words': [{'word': 'I',
#       'start': 59.88,
#       'end': 59.9,
#       'score': 0.53,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'have',
#       'start': 59.9,
#       'end': 59.9,
#       'score': 0.07,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'a',
#       'start': 59.9,
#       'end': 60.06,
#       'score': 0.11,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'good',
#       'start': 60.06,
#       'end': 60.14,
#       'score': 0.85,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'one',
#       'start': 60.14,
#       'end': 60.38,
#       'score': 0.61,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'of',
#       'start': 60.38,
#       'end': 60.56,
#       'score': 0.01,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'them',
#       'start': 60.56,
#       'end': 60.98,
#       'score': 0.23,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'I',
#       'start': 60.98,
#       'end': 61.1,
#       'score': 0.4,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'never',
#       'start': 61.1,
#       'end': 61.3,
#       'score': 0.4,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'had',
#       'start': 61.3,
#       'end': 61.62,
#       'score': 0.38,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'one',
#       'start': 61.62,
#       'end': 61.86,
#       'score': 0.79,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'like',
#       'start': 61.86,
#       'end': 62.06,
#       'score': 0.04,
#       'speaker': 'SPEAKER_03'},
#      {'word': 'this',
#       'start': 62.06,
#       'end': 62.3,
#       'score': 0.81,
#       'speaker': 'SPEAKER_00'},
#      {'word': 'never',
#       'start': 62.3,
#       'end': 62.86,
#       'score': 0.22,
#       'speaker': 'SPEAKER_00'}]}]},
#  'video_summary': {'summary': SummaryResponse(main_idea='This video showcases various cats and their owners at a cat show, highlighting the diversity of breeds and the affectionate bond between humans and their feline companions.', theme=['cats', 'competition'], video_type=['social media video', 'vlog'], synopsis='The video features several people holding and presenting their cats, often adorned in costumes or interacting with cat-specific items like scratching posts. The scenes are set indoors, likely at a cat show, as indicated by the signage and background elements such as cages and judging tables. The amateur handheld footage offers a casual, up-close look at the event and the cats themselves.', plot='man holds cat, woman holds cat in bee costume, man holds calico cat, man holds tabby cat, man holds orange cat, man holds ginger cat, man sits as cat walks.'),
#   'input_tokens': 2546,
#   'output_tokens': 192},
#  'usage': {'cp_input_tokens': 6552,
#   'cp_output_tokens': 2219,
#   'gm_input_tokens': 2546,
#   'gm_output_tokens': 192}}
