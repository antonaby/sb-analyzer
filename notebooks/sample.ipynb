# %%
from core.apify import create_apify_client, download_video
from core.videos import split_video

client = create_apify_client()

# %%
video = await download_video(client, "jwdW1aEE7nZB6behY", "video-abrajerril-20251001021835-7556071963177831711.mp4")
frames = split_video(video, interval_seconds=10)

# %%
from core.agents.analyzer import VideoAnalyzer

analyzer = VideoAnalyzer()

result = await analyzer.analyze(frames)
result
# Out:
# [({'base64': '...',
#    'frame_number': 0,
#    'timestamp': 0},
#   ClipTaggerResponse(description='A calico cat walks across a paved patio towards the camera. The cat is carrying several small kittens in its mouth. In the background, there is a pink vending machine, a wooden fence, and some outdoor furniture. White text with a black outline is overlaid on the bottom of the image.', objects=['Calico cat', 'Kittens', 'Paved patio', 'Pink vending machine', 'Wooden fence', 'Red plastic chair', 'English text', 'Emoji', 'White hose', 'Weeds'], actions=['A cat walking towards the camera on a patio.', 'A cat carrying kittens in its mouth.'], environment='An outdoor paved patio or backyard area with a wooden fence, a vending machine, and various pieces of outdoor furniture. The ground is made of light-colored paving stones with some weeds growing through them.', content_type='real-world footage', specific_style='Social media video', production_quality='amateur handheld', summary='A calico cat walks across a paved patio while carrying several kittens in its mouth, with text overlaid on the image.', logos=[])),
#  ({'base64': '...',
#    'frame_number': 300,
#    'timestamp': 10},
#   ClipTaggerResponse(description='A large, fluffy grey cat is holding a small, wet kitten. The kitten has blue eyes and is looking directly at the camera. They are positioned on a dark, patterned rug. White text is overlaid on the image.', objects=['Mother cat with long, fluffy grey fur', 'Kitten with wet, grey fur and blue eyes', 'Patterned rug with a dark grey and white design', 'English text that reads "Mom\'s cleaning her babies after a nice meal"'], actions=['A mother cat holding her kitten', 'A kitten looking at the camera'], environment='An indoor setting with a dark, patterned rug on the floor and a light-colored wall in the background.', content_type='real-world footage', specific_style='social media video', production_quality='amateur handheld', summary='A mother cat holds her small, wet kitten on a patterned rug, with text overlaid on the image.', logos=[])),
#  ({'base64': '...',
#    'frame_number': 600,
#    'timestamp': 20},
#   ClipTaggerResponse(description="A close-up, high-angle view shows a tabby cat with dark fur and white markings on its chest and paws. The cat is standing on a brown carpeted surface, which appears to be a cat tree. In the background, a white door frame and a light-colored wall are visible. The cat's head is turned slightly downwards.", objects=['Tabby cat with dark fur and white markings', 'Brown carpet', 'Yellow pole', 'White door frame', 'Light-colored wall'], actions=['A cat standing on a carpeted surface.'], environment='The setting is indoors, likely a room in a house, with a brown carpeted floor and a white door frame against a light-colored wall. The lighting is ambient and appears to be from an indoor source.', content_type='real-world footage', specific_style='pet video', production_quality='amateur handheld', summary='A close-up, high-angle shot shows a tabby cat standing on a brown carpeted cat tree inside a room.', logos=[])),
#  ({'base64': '...',
#    'frame_number': 900,
#    'timestamp': 30},
#   ClipTaggerResponse(description='A mother cat with a spotted and striped coat is sitting in a light-colored pet bed. She is holding a litter of several small kittens that have a similar spotted and striped pattern. The mother cat is looking directly forward with wide eyes. The kittens are nestled against her body.', objects=['Mother cat with a spotted and striped coat', 'Kittens with a spotted and striped coat', 'Pet bed with a light-colored, soft interior', 'White wall', 'White baseboard'], actions=['A mother cat holding her kittens', 'A mother cat looking at the camera'], environment='An indoor setting, likely a room in a home, with a pet bed placed against a wall with a white baseboard. The lighting is artificial and warm.', content_type='real-world footage', specific_style='pet video', production_quality='amateur handheld', summary='A mother Bengal cat sits in a pet bed while holding her litter of kittens and looking directly at the camera.', logos=[])),
#  ({'base64': '...',
#    'frame_number': 1200,
#    'timestamp': 40},
#   ClipTaggerResponse(description='A large, light brown cat with a black collar stands on a bed, looking towards the right. Behind it, a smaller, similar-looking cat sits on the bed. The bed has a grey comforter with a white pattern and a grey pillow. In the background, a lamp with a white shade is lit.', objects=['Large light brown cat', 'Small light brown cat', 'Black collar', 'Bed', 'Grey comforter with a white pattern', 'Grey pillow', 'Lamp with a white shade', 'English text'], actions=['A large cat standing on a bed', 'A small cat sitting on a bed'], environment='The setting is an indoor bedroom with warm, dim lighting. The scene is centered on a bed with a grey patterned comforter and a pillow, with a lit lamp visible in the background.', content_type='real-world footage', specific_style='social media video', production_quality='amateur handheld', summary='A large light brown cat stands on a bed in front of a smaller cat, with white text overlaid at the bottom.', logos=[])),
#  ({'base64': '...',
#    'frame_number': 1500,
#    'timestamp': 50},
#   ClipTaggerResponse(description='A black cat with yellow eyes is lying down on a light-colored, textured surface. The cat is looking directly at the camera. In the background, there are some papers and a brown, textured object. The scene is dimly lit.', objects=['Black cat with yellow eyes and black fur.', 'Light-colored textured blanket.', 'White papers in the background.', 'Brown textured object, possibly a pillow or blanket.'], actions=['A black cat lying down on a surface.', 'A black cat looking towards the camera.'], environment='The setting appears to be an indoor space, possibly a room in a house, with dim, warm lighting. The cat is resting on a soft, textured surface like a blanket or bed.', content_type='real-world footage', specific_style='pet video', production_quality='amateur handheld', summary='A black cat with yellow eyes lies on a textured surface and looks directly at the camera in a dimly lit room.', logos=[])),
#  ({'base64': '...',
#    'frame_number': 1800,
#    'timestamp': 60},
#   ClipTaggerResponse(description="A person's hand holds a small, light-colored kitten in the foreground. The kitten is looking towards a larger, brown tabby cat that is partially visible behind a wooden post. The scene takes place outdoors on a gravel surface next to a wooden structure. White text is overlaid on the top left of the image.", objects=['Kitten', 'Cat', 'Human hand', 'Wooden post', 'Gravel', 'Wooden structure', 'English text'], actions=['A person holding a kitten', 'A kitten looking at a cat'], environment='An outdoor setting, likely a backyard or patio, with a gravel ground, a wooden post, and a wooden structure. The lighting appears to be natural daylight.', content_type='real-world footage', specific_style='Social media video', production_quality='amateur handheld', summary='A person holds a small kitten that is looking at a larger cat in an outdoor setting, with text overlaid on the image.', logos=[]))]
