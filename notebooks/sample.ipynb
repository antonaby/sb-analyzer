# %%
from core.apify import create_apify_client, download_video
from core.videos import split_video

client = create_apify_client()

# %%
video = await download_video(client, "jwdW1aEE7nZB6behY", "video-abrajerril-20251001021835-7556071963177831711.mp4")
frames = split_video(video)

# %%
from core.agents.analyzer import VideoAnalyzer

analyzer = VideoAnalyzer()

result = await analyzer._analyze_frame(frames[0])
result
# Out:
# ClipTaggerResponse(description='A calico cat walks towards the camera on a paved patio, followed by a smaller tabby cat. In the background, there is a pink and white vending machine, a wooden pallet, and a red plastic chair. The patio is made of light-colored paving stones, and there are weeds growing through the cracks. White text with a black outline is overlaid on the bottom of the image.', objects=['Calico cat', 'Tabby cat', 'Paved patio', 'Vending machine', 'Wooden pallet', 'Red plastic chair', 'English text', 'Weeds'], actions=['A cat walking towards the camera on a patio.', 'A cat following another cat.'], environment='An outdoor paved patio or backyard with light-colored paving stones. The area appears somewhat cluttered with a vending machine, a pallet, and a plastic chair, with weeds growing through the cracks in the pavement.', content_type='real-world footage', specific_style='Social media video', production_quality='amateur handheld', summary='A calico cat walks towards the camera on a paved patio, followed by a smaller tabby cat, with text overlaid on the image.', logos=[])
