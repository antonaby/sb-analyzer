# %%
from core.apify.client import ApifyClient

client = ApifyClient()
api_dojo_scrapper = client.apidojo_tiktok_scrapper()

# %%
run, dataset = await api_dojo_scrapper.search(keywords=["cat", "cats", "kitty"], date_range="THIS_WEEK", sort_type="MOST_LIKED", max_items=10)
dataset
