# %%
from core.apify.tiktok import TikTokPost

post: TikTokPost = {
    "id": "7556797968859352334",
    "text": "Cat at the wedding #cat #funnycat #cats #funnyvideos #fyp ",
    "textLanguage": "en",
    "createTime": 1759454168,
    "createTimeISO": "2025-10-03T01:16:08.000Z",
    "isAd": False,
    "authorMeta": {
        "id": "7438120718305870890",
        "name": "catfunny36",
        "profileUrl": "https://www.tiktok.com/@catfunny36",
        "nickName": "Cat funny36",
        "verified": False,
        "signature": "",
        "bioLink": None,
        "originalAvatarUrl": "https://p16-common-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/39f9e5313b11a219ff8566774a5fb79e~tplv-tiktokx-cropcenter:720:720.jpeg?dr=9640&refresh_token=6e3eb79a&x-expires=1759647600&x-signature=IBCxOVG%2Fs1PcEqz%2FyO57xaN%2B4yc%3D&t=4d5b0474&ps=13740610&shp=a5d48078&shcp=81f88b70&idc=useast5",
        "avatar": "https://p16-common-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/39f9e5313b11a219ff8566774a5fb79e~tplv-tiktokx-cropcenter:720:720.jpeg?dr=9640&refresh_token=6e3eb79a&x-expires=1759647600&x-signature=IBCxOVG%2Fs1PcEqz%2FyO57xaN%2B4yc%3D&t=4d5b0474&ps=13740610&shp=a5d48078&shcp=81f88b70&idc=useast5",
        "privateAccount": False,
        "following": 3,
        "friends": 0,
        "fans": 933300,
        "heart": 58600000,
        "video": 159,
        "digg": 437
    },
    "musicMeta": {
        "musicName": "The Winner Is... - DeVotchKa Version",
        "musicAuthor": "DeVotchKa",
        "musicOriginal": False,
        "musicAlbum": "The Winner Is... - DeVotchKa Version",
        "playUrl": "https://sf16.tiktokcdn-us.com/obj/tos-alisg-ve-2774/owFrY6QZqts8KunkBqgeX3iyQbw3kWDBTdHDfC",
        "coverMediumUrl": "https://p16-common.tiktokcdn-us.com/tos-alisg-v-2774/o43CGBD7JonAZNgzyIAreufBbMQAGkItv6IbNU~tplv-tiktokx-cropcenter:200:200.jpeg?dr=9584&t=4d5b0474&ps=933b5bde&shp=08d74b56&shcp=81f88b70&idc=useast5",
        "originalCoverMediumUrl": "https://p16-common.tiktokcdn-us.com/tos-alisg-v-2774/o43CGBD7JonAZNgzyIAreufBbMQAGkItv6IbNU~tplv-tiktokx-cropcenter:200:200.jpeg?dr=9584&t=4d5b0474&ps=933b5bde&shp=08d74b56&shcp=81f88b70&idc=useast5",
        "musicId": "7268735501090539521"
    },
    "webVideoUrl": "https://www.tiktok.com/@catfunny36/video/7556797968859352334",
    "mediaUrls": [
        "https://api.apify.com/v2/key-value-stores/NmjTBbquqMg8SmoAC/records/video-catfunny36-20251003011608-7556797968859352334.mp4"
    ],
    "videoMeta": {
        "height": 778,
        "width": 576,
        "duration": 69,
        "coverUrl": "https://p16-common-sign.tiktokcdn-us.com/tos-useast5-p-0068-tx/oACHjpGRv9keTXEwekeXk8JIGwpLQIRaHgAA64~tplv-tiktokx-origin.image?dr=9636&x-expires=1759647600&x-signature=U9Q51w6S0s5QS%2ByZfIsn70TBPc4%3D&t=4d5b0474&ps=13740610&shp=81f88b70&shcp=43f4a2f9&idc=useast5",
        "originalCoverUrl": "https://p16-common-sign.tiktokcdn-us.com/tos-useast5-p-0068-tx/oACHjpGRv9keTXEwekeXk8JIGwpLQIRaHgAA64~tplv-tiktokx-origin.image?dr=9636&x-expires=1759647600&x-signature=U9Q51w6S0s5QS%2ByZfIsn70TBPc4%3D&t=4d5b0474&ps=13740610&shp=81f88b70&shcp=43f4a2f9&idc=useast5",
        "definition": "540p",
        "format": "mp4",
        "downloadAddr": "https://api.apify.com/v2/key-value-stores/NmjTBbquqMg8SmoAC/records/video-catfunny36-20251003011608-7556797968859352334.mp4"
    },
    "diggCount": 12700,
    "shareCount": 1605,
    "playCount": 91400,
    "collectCount": 1389,
    "commentCount": 89,
    "mentions": [],
    "detailedMentions": [],
    "hashtags": [
        {"name": "cat"},
        {"name": "funnycat"},
        {"name": "cats"},
        {"name": "funnyvideos"},
        {"name": "fyp"}
    ],
    "effectStickers": [
        {
            "ID": "454747",
            "name": "Green Screen Video",
            "stickerStats": {
                "useCount": 0
            }
        }
    ],
    "isSlideshow": False,
    "isPinned": False,
    "isSponsored": False,
    "input": "cats",
    "searchHashtag": {
        "views": 363400000000,
        "name": "cats"
    }
}

# %%
from core.file import UrlVideoSource

source = await UrlVideoSource.new("https://api.apify.com/v2/key-value-stores/NmjTBbquqMg8SmoAC/records/video-catfunny36-20251003011608-7556797968859352334.mp4", "./videos")
source.get_video_file_path()
# Out:
# '/home/anton/projects/sb-videoanalyzer/videos/video-catfunny36-20251003011608-7556797968859352334.mp4'

# %%
from core.file import VideoFile, AudioFile

video = VideoFile(source)
print(f"duration: {video.get_duration()}, frames: {video.get_total_frames()}")
audio = AudioFile(source)
# Out:
# duration: 69.9, frames: 2097

# %%
from core.agents.video import ClipTaggerClient, VideoData
from core.agents.transcribe import LemonfoxClient, AudioData

ct_client = ClipTaggerClient()
lm_client = LemonfoxClient()

video_data = VideoData(ct_client, video)
audio_data = AudioData(lm_client, audio)

# %%
from core.agents.summary import SummaryAgent

agent = SummaryAgent()

summary = await agent.summary_tiktok(post, video_data, audio_data)
summary
# Out:
# VideoSummary(main_idea='A compilation of funny and heartwarming moments featuring a cat interacting with people during what appears to be a wedding or formal event.', theme=['Cats', 'Weddings', 'Humor'], video_type=['shortform', 'funnyvideos', 'vlog'], synopsis=['A woman in a wedding dress stands on a path while a small cat lies on the grass nearby.', 'A man in a suit and a woman in a wedding dress bow their heads over a ginger cat sitting on a stool.', 'A small tabby cat peeks out from under a white sheet on a paved surface.', 'A person records a white toy car with flowers on its hood.', 'A white and orange spotted cat lies on a stone patio next to green grass.', 'Two people stand in a bedroom while a white cat sits on a bed.', 'A bride bends over a baby stroller containing a cat during a ceremony.', 'A man in a suit kisses an orange cat he is holding.', 'Two women stand with a cat and a dog in a decorated room.', 'A black cat with white paws lies stretched out on a paved stone surf
# ...

# %%
source.delete()
