# %%
from core.videos import VideoFile

file = VideoFile("./videos/video.mp4")
print(f"duration: {file.get_duration()}, frames: {file.get_total_frames()}")
# Out:
# duration: 68.8, frames: 2064

# %%
frame1 = file.get_frame(68.8)
frame1
# Out:
# {'base64': '...',
#  'frame_number': 2063,
#  'timestamp': 68.8}

# %%
import os

from pydantic_ai import Agent
from pydantic_ai.models.google import GoogleModel
from pydantic_ai.providers.google import GoogleProvider

key = os.getenv("GOOGLE_API_KEY")
key


model = GoogleModel('gemini-2.5-flash-lite-preview-09-2025')
agent = Agent(model)

#await agent.run("Say Hi!")
