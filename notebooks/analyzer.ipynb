# %%
from core.apify.tiktok.apidojo import TikTokPost

post: TikTokPost = {
    "id": "7556464954786794763",
    "title": "cat stealing a fish, sora AI #ia #ai #cat ",
    "textLanguage": "en",
    "views": 206417724,
    "likes": 12632715,
    "comments": 136371,
    "shares": 4745494,
    "bookmarks": 1032698,
    "hashtags": [
      "ia",
      "ai",
      "cat"
    ],
    "channel": {
      "name": "elhechicero",
      "username": "animandopinterest",
      "id": "6898509309971121153",
      "url": "https://www.tiktok.com/@animandopinterest",
      "avatar": "https://p16-common-sign.tiktokcdn-us.com/tos-maliva-avt-0068/ab9f3d7826eeac7131195a9e55c3ead3~tplv-tiktokx-cropcenter:1080:1080.webp?dr=9640&refresh_token=10e8693a&x-expires=1759924800&x-signature=vo%2FU0%2FJqW4%2BFjsgVtLzteK%2BoZQA%3D&t=4d5b0474&ps=13740610&shp=d05b14bd&shcp=34ff8df6&idc=useast8",
      "verified": False,
      "followers": 91702,
      "following": 3
    },
    "uploadedAt": 1759376611,
    "uploadedAtFormatted": "2025-10-02T03:43:31.000Z",
    "video": {
      "width": 576,
      "height": 1048,
      "ratio": "540p",
      "duration": 10.067,
      "url": "https://v16m.tiktokcdn-us.com/a52b1466cff25630139a0f3eaa95a10a/68e557e2/video/tos/useast2a/tos-useast2a-ve-0068c003/oQORceed5AnGGYERAwZIA9Ek9FdLg1w9jimDff/?a=1233&bti=NEBzNTY6QGo6OjZALnAjNDQuYCMxNDNg&ch=0&cr=13&dr=0&er=0&lr=all&net=0&cd=0%7C0%7C0%7C&cv=1&br=2032&bt=1016&cs=0&ds=6&ft=arR-Iq4fmbdPD12cHq9T3wUg0cZAMeF~O5&mime_type=video_mp4&qs=0&rc=OWhpOGY8NTczNWQ2NWZkPEBpanJqaXA5cnF5NjMzNzczM0AuY2E1NjExXl8xYmNgMC4xYSNncG81MmRrNmJhLS1kMTZzcw%3D%3D&vvpl=1&l=20251007121135FDF42B40C6562E1F7B81&btag=e000b0000",
      "cover": "https://p19-common-sign.tiktokcdn-us.com/tos-maliva-p-0068/oIFLInkGcRNehbDOFtAFYdO2Ef9cjeEEfAmsdA~tplv-x7g4mazu7z-crop-80-heic:500:800.heic?biz_tag=musically_video.video_cover&dr=9616&ftpl=1&idc=useast8&ps=13740610&refresh_token=7078e2f5&shcp=9b759fb9&shp=c1333099&t=4d5b0474&x-expires=1759860000&x-signature=CKdt1GU9bfaWetYfXnsVJ4csBbo%3D",
          "https://v19-cla.tiktokcdn-us.com/8f6631eb8d489f7bd1bf398764c48364/690c9082/video/tos/useast2a/tos-useast2a-v-0068/38acaa54d50d4232be3106c10f2b0559/?a=1233&bti=NEBzNTY6QGo6OjZALnAjNDQuYCMxNDNg&ch=0&cr=13&dr=0&er=0&lr=all&net=0&cd=0%7C0%7C0%7C&cv=1&br=5546&bt=2773&cs=0&ds=3&ft=aEdJYq4fmbdPD12cHq9T3wUg0cZAMeF~O5&mime_type=video_mp4&qs=13&rc=anJqaXA5cnF5NjMzNzczM0BpanJqaXA5cnF5NjMzNzczM0BncG81MmRrNmJhLS1kMTZzYSNncG81MmRrNmJhLS1kMTZzcw%3D%3D&vvpl=1&l=20251007121135FDF42B40C6562E1F7B81&btag=e00070000",
          "https://api16-normal-useast8.tiktokv.us/aweme/v1/play/?faid=1233&format=webvtt&is_play_url=1&language=eng-US&line=0&signaturev3=dmlkZW9faWQ7ZmlsZV9pZDtpdGVtX2lkLjdjMGI3YTlkY2ZlYjA3Yjc5ZDI5MjE2YWY2ZGQ4YWU3&source=SmartPlayerSubtitleRedirect&version=1%3Abig_caption&video_id=v09044g40000d3ev9nnog65m8frgsojg"
        ],
        "variant": "big_caption"
      }
    ],
    "postPage": "https://www.tiktok.com/@animandopinterest/video/7556464954786794763",
    "keyword": "cat"
  }

# %%
from core.processors import TikTokVideoProcessor
from core.agents.video import ClipTaggerClient
from core.agents.transcribe import LemonfoxClient
from core.agents.summary import SummaryAgent

ct_client = ClipTaggerClient()
lm_client = LemonfoxClient()
agent = SummaryAgent()

# %%
processor = TikTokVideoProcessor(ct_client, lm_client, agent, "./videos")
summary = await processor.process_video(post)
summary
# Out:
# VideoSummary(main_idea='A short, candid video showing various animals, primarily cats, appearing in unexpected public or commercial settings like a grocery store and a parking lot.', theme=['Animals in public', 'Unexpected encounters'], video_type=['shortform', 'candid video', 'vlog'], synopsis=['An orange cat is inside a refrigerated display case sniffing a fish.', 'A small bird walks across the polished floor of a large retail store.', "A small, light-brown cat walks across the tiled floor of a building's lobby.", 'A small cat walks across the floor of a building lobby towards the exit.', 'A small, light-colored cat walks across a large, paved parking lot.', 'A small, light-brown dog runs across a paved parking lot at dusk.'])
