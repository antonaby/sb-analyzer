# %%
from models.common import PostDetails

post: PostDetails = {
  "url": "https://www.tiktok.com/@qaswaofficial/video/7560684952518446391",
  "likes": 16152920,
  "title": "Cute #cat #kitty #meow #baby",
  "views": 76385754,
  "source": {
    "id": "7560684952518446391",
    "title": "Cute #cat #kitty #meow #baby ",
    "textLanguage": "en",
    "views": 188082,
    "likes": 14713,
    "comments": 101,
    "shares": 4857,
    "bookmarks": 682,
    "hashtags": [
      "cat",
      "kitty",
      "meow",
      "baby"
    ],
    "channel": {
      "name": "Qaswa",
      "username": "qaswaofficial",
      "id": "7530084418138063927",
      "url": "https://www.tiktok.com/@qaswaofficial",
      "avatar": "https://p16-common-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/c8f3f88acca33259dc9812dff56d1ba8~tplv-tiktokx-cropcenter:1080:1080.webp?dr=9640&refresh_token=2f6c054c&x-expires=1760590800&x-signature=mijrp3jcg%2BfVIEVB%2BiVN2cqaz1Q%3D&t=4d5b0474&ps=13740610&shp=d05b14bd&shcp=34ff8df6&idc=useast8",
      "verified": False,
      "followers": 28933
    },
    "uploadedAt": 1760359207,
    "uploadedAtFormatted": "2025-10-13T12:40:07.000Z",
    "video": {
      "width": 576,
      "height": 1048,
      "ratio": "540p",
      "duration": 10.101,
      "url": "https://v16m.tiktokcdn-us.com/6a5eaf61c8a9c8530e66a59a09be0020/68ef86b0/video/tos/useast5/tos-useast5-ve-0068c003-tx/oo0grf8vA2LEPzSoRE5BDQ0zyEE2IQFsiHB7fD/?a=1233&bti=NEBzNTY6QGo6OjZALnAjNDQuYCMxNDNg&ch=0&cr=13&dr=0&er=0&lr=all&net=0&cd=0%7C0%7C0%7C&cv=1&br=2486&bt=1243&cs=0&ds=6&ft=WgSBMNdkVcy5Uxl7KStG-XD5SK46MjPXttz_CAMyqF_4&mime_type=video_mp4&qs=0&rc=NzhlOmlkPDs1Z2QzO2g2ZUBpank7b3M5cnVpNjMzZzczNEBgLzU2LmFiNTUxNDMtNjYxYSNwZGNxMmRzMmphLS1kMS9zcw%3D%3D&vvpl=1&l=20251015053357FC6157D7A271160574C3&btag=e000b0000",
      "cover": "https://p16-common-sign.tiktokcdn-us.com/tos-useast5-p-0068-tx/oge7YdAkIIftpOAOe5jRZGjJsQzVILAeAAQLHG~tplv-tiktokx-cropcenter:500:800.jpeg?biz_tag=musically_video.video_cover&dr=9638&idc=useast8&ps=13740610&refresh_token=d38227d9&shcp=9b759fb9&shp=c1333099&t=4d5b0474&x-expires=1760526000&x-signature=GVgOsU5%2Fj6MXvTQNEsCbALaSI7U%3D",
      "thumbnail": "https://p16-common-sign.tiktokcdn-us.com/tos-useast5-p-0068-tx/oge7YdAkIIftpOAOe5jRZGjJsQzVILAeAAQLHG~tplv-tiktokx-cropcenter:500:800.jpeg?biz_tag=musically_video.video_cover&dr=9638&idc=useast8&ps=13740610&refresh_token=d38227d9&shcp=9b759fb9&shp=c1333099&t=4d5b0474&x-expires=1760526000&x-signature=GVgOsU5%2Fj6MXvTQNEsCbALaSI7U%3D"
    },
    "song": {
      "id": "7560685001633762062",
      "title": "original sound - qaswaofficial",
      "artist": "Qaswa",
      "duration": 10,
      "cover": "https://p16-common-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/c8f3f88acca33259dc9812dff56d1ba8~tplv-tiktokx-cropcenter:1080:1080.webp?dr=9640&refresh_token=2f6c054c&x-expires=1760590800&x-signature=mijrp3jcg%2BfVIEVB%2BiVN2cqaz1Q%3D&t=4d5b0474&ps=13740610&shp=d05b14bd&shcp=34ff8df6&idc=useast8"
    },
    "postPage": "https://www.tiktok.com/@qaswaofficial/video/7560684952518446391"
  },
  "scraper": "apidojo",
  "comments": 24304,
  "hashtags": [
    "cat",
    "kitty",
    "meow",
    "baby"
  ],
  "post_from": "tiktok",
  "search_id": "79905be4-a820-11f0-a230-43474dd78a4d",
  "description": "",
  "download_url": "https://v16m.tiktokcdn-us.com/6a5eaf61c8a9c8530e66a59a09be0020/68ef86b0/video/tos/useast5/tos-useast5-ve-0068c003-tx/oo0grf8vA2LEPzSoRE5BDQ0zyEE2IQFsiHB7fD/?a=1233&bti=NEBzNTY6QGo6OjZALnAjNDQuYCMxNDNg&ch=0&cr=13&dr=0&er=0&lr=all&net=0&cd=0%7C0%7C0%7C&cv=1&br=2486&bt=1243&cs=0&ds=6&ft=WgSBMNdkVcy5Uxl7KStG-XD5SK46MjPXttz_CAMyqF_4&mime_type=video_mp4&qs=0&rc=NzhlOmlkPDs1Z2QzO2g2ZUBpank7b3M5cnVpNjMzZzczNEBgLzU2LmFiNTUxNDMtNjYxYSNwZGNxMmRzMmphLS1kMS9zcw%3D%3D&vvpl=1&l=20251015053357FC6157D7A271160574C3&btag=e000b0000",
  "uploaded_at_iso": "2025-10-07T17:27:33+00:00"
}

# %%
from core.agents.summary import SummaryAgent
from core.agents.tpl import TemplateManager
from core.transcribe import AudioData, LemonfoxClient, Transcription
from core.video import ClipTaggerClient, VideoData, Frame
from core.file import AudioFile, UrlVideoSource, VideoFile

clip_tagger_client = ClipTaggerClient()
lemonfox_client = LemonfoxClient()
summary_agent = SummaryAgent(TemplateManager())

video_source = await UrlVideoSource.new(post["download_url"], "./videos")

video_file = VideoFile(video_source)  
audio_file = AudioFile(video_source)

video_data = VideoData(clip_tagger_client, video_file)
audio_data = AudioData(lemonfox_client, audio_file)

# %%
summary = await summary_agent.summary(post, video_data, audio_data)
summary

# %%
video_source.delete()
