# %%
from models.common import PostDetails

post: PostDetails = {
  "url": "https://www.tiktok.com/@qaswaofficial/video/7560684952518446391",
  "likes": 16152920,
  "title": "Cute #cat #kitty #meow #baby",
  "views": 76385754,
  "source": {
    "id": "7561385175691578638",
    "title": "#kittensoftiktok #cutecat #kitty #cutekitten #foru ",
    "textLanguage": "un",
    "views": 27313,
    "likes": 5708,
    "comments": 15,
    "shares": 2956,
    "bookmarks": 459,
    "hashtags": [
      "kittensoftiktok",
      "cutecat",
      "kitty",
      "cutekitten",
      "foru"
    ],
    "channel": {
      "name": "Catloverclub007",
      "username": "catloverclub007",
      "id": "7519116718427800631",
      "url": "https://www.tiktok.com/@catloverclub007",
      "avatar": "https://p16-common-sign.tiktokcdn-us.com/tos-useast8-avt-0068-tx2/281974b1eff6cd5ea6c69fcea91c6735~tplv-tiktokx-cropcenter:1080:1080.webp?dr=9640&refresh_token=6888f691&x-expires=1760677200&x-signature=Mb60Zf9Rxp7qWOVsGppTbNxR4KI%3D&t=4d5b0474&ps=13740610&shp=d05b14bd&shcp=34ff8df6&idc=useast8",
      "verified": False,
      "followers": 1384,
      "following": 1
    },
    "uploadedAt": 1760522194,
    "uploadedAtFormatted": "2025-10-15T09:56:34.000Z",
    "video": {
      "width": 576,
      "height": 1024,
      "ratio": "540p",
      "duration": 11.403,
      "url": "https://v16m.tiktokcdn-us.com/6438bdbf3ab6159327d09004c0930a79/68f0d6ae/video/tos/useast5/tos-useast5-pve-0068-tx/okvlozAxigv39U0OB4Zta7biIKjB98cqPUEUE/?a=1233&bti=NEBzNTY6QGo6OjZALnAjNDQuYCMxNDNg&ch=0&cr=13&dr=0&er=0&lr=all&net=0&cd=0%7C0%7C0%7C&cv=1&br=950&bt=475&cs=0&ds=6&ft=WgSBMNdkVcy5Uxl7KStG-XD5Sv4W1jPXtYxvt-cyqF_4&mime_type=video_mp4&qs=0&rc=ZTZmOTc0NzQ1NTs6NGY5NEBpM3VlOG45cm1wNjMzZzczNEAyYTUwNDViXy8xNmFeMV5hYSNoMDJiMmQ0c2thLS1kMS9zcw%3D%3D&vvpl=1&l=202510160527307F839B19359DC2042EA4&btag=e000b0000",
      "cover": "https://p16-common-sign.tiktokcdn-us.com/tos-useast5-p-0068-tx/o8RO0Dzix4QUaBqK9UBo97OEIgtcvIEvABPib~tplv-tiktokx-cropcenter:500:800.jpeg?biz_tag=musically_video.video_cover&dr=9638&idc=useast8&ps=13740610&refresh_token=3eaf0b98&shcp=9b759fb9&shp=c1333099&t=4d5b0474&x-expires=1760612400&x-signature=h3103gqBQ26gL0NNDCfpV7Vk3sY%3D",
      "thumbnail": "https://p16-common-sign.tiktokcdn-us.com/tos-useast5-p-0068-tx/o8RO0Dzix4QUaBqK9UBo97OEIgtcvIEvABPib~tplv-tiktokx-cropcenter:500:800.jpeg?biz_tag=musically_video.video_cover&dr=9638&idc=useast8&ps=13740610&refresh_token=3eaf0b98&shcp=9b759fb9&shp=c1333099&t=4d5b0474&x-expires=1760612400&x-signature=h3103gqBQ26gL0NNDCfpV7Vk3sY%3D"
    },
    "song": {
      "id": "7561385168133475127",
      "title": "original sound - catloverclub007",
      "artist": "Catloverclub007",
      "duration": 11,
      "cover": "https://p16-common-sign.tiktokcdn-us.com/tos-useast8-avt-0068-tx2/281974b1eff6cd5ea6c69fcea91c6735~tplv-tiktokx-cropcenter:1080:1080.webp?dr=9640&refresh_token=6888f691&x-expires=1760677200&x-signature=Mb60Zf9Rxp7qWOVsGppTbNxR4KI%3D&t=4d5b0474&ps=13740610&shp=d05b14bd&shcp=34ff8df6&idc=useast8"
    },
    "postPage": "https://www.tiktok.com/@catloverclub007/video/7561385175691578638"
  },
  "scraper": "apidojo",
  "comments": 24304,
  "hashtags": [
    "cat",
    "kitty",
    "meow",
    "baby"
  ],
  "post_from": "tiktok",
  "search_id": "79905be4-a820-11f0-a230-43474dd78a4d",
  "description": "",
  "download_url": "https://v45.tiktokcdn-eu.com/f55b495aa57e9cf8b32449933e8fd548/68f34a30/video/tos/no1a/tos-no1a-ve-0068-no/oUJLm2RIUSeMrDffAzIvP8QmWIAjvg1g9icYDQ/?a=1233&bti=MzU8OGYpNHYpNzo5ZjEuLjpkLTptNDQwOg%3D%3D&ch=0&cr=13&dr=0&er=0&lr=all&net=0&cd=0%7C0%7C0%7C&cv=1&br=2856&bt=1428&cs=0&ds=6&ft=XsFb8q4fmbdPD12-fPIT3wUVulrtaeF~O5&mime_type=video_mp4&qs=0&rc=Mzg2OjY1OGlkPGc3ZDs4N0Bpaml5am45cnA6NjMzbzczNUAtLi5fLTMzNWIxNmBfNTJiYSM1YmYuMmRjcWlhLS1kMTFzcw%3D%3D&vvpl=1&l=202510170804548DFD3F4FAEB334009109&btag=e000b5000",
  "uploaded_at_iso": "2025-10-07T17:27:33+00:00"
}

# %%
from core.agents.summary import SummaryAgent
from core.agents.common import TemplateManager
from core.agents.common import TopicManager, TopicAgent, gemini_2_5_flash_lite
from core.transcribe import AudioData, LemonfoxClient
from core.video import ClipTaggerClient, VideoData
from core.file import AudioFile, UrlVideoSource, VideoFile
from db.conf import create_db_engine, get_async_session

engine = create_db_engine()
db = get_async_session(engine)

tpl_manager = TemplateManager()
clip_tagger_client = ClipTaggerClient()
lemonfox_client = LemonfoxClient()
topic_manager = TopicManager(db)
model = gemini_2_5_flash_lite()
topic_agent = TopicAgent(model, tpl_manager, topic_manager)
summary_agent = SummaryAgent(model, tpl_manager, topic_agent)

video_source = await UrlVideoSource.new(post["download_url"], "./videos")

video_file = VideoFile(video_source)  
audio_file = AudioFile(video_source)

video_data = VideoData(clip_tagger_client, video_file)
audio_data = AudioData(lemonfox_client, audio_file)

# %%
summary = await summary_agent.run(post, video_data, audio_data, temperature=0.1)
summary

# %%
video_source.delete()
