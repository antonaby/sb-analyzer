# %%
from core.agents.video import ClipTaggerClient
from core.agents.transcribe import LemonfoxClient
from core.agents.summary import SummaryAgent

from db.conf import create_db_engine, get_async_session
from core.processors.scraper import ScraperProcessor
from core.processors.video import VideoProcessor

engine = create_db_engine()
db = get_async_session(engine)
s_processor = ScraperProcessor(db)

ct_client = ClipTaggerClient()
lm_client = LemonfoxClient()
agent = SummaryAgent()

v_processor = VideoProcessor(ct_client, lm_client, agent, db, "./videos")

# %%
from models.common import AuthorDetails, PostDetails

author: AuthorDetails = {
  "author_from": "tiktok",
  "url": "https://www.tiktok.com/@br0pics"
}

post: PostDetails = {
  "url": "https://www.tiktok.com/@br0pics/video/7540986521684380960",
  "download_url": "https://www.tiktok.com/@br0pics/video/7540986521684380960",
  "post_from": "tiktok",
  "title": "test",
  "description": "test",
  "hashtags": [],
  "scraper": "apidojo",
  "source": {
    "test": "test 3"
  }
}

# %%
#s_result = await s_processor.save_video(author, post)
#s_result

# %%
from uuid import UUID

v_result = await v_processor.run(UUID("e33e4b82-a5aa-11f0-bef2-5368ed8c6949"))
v_result
